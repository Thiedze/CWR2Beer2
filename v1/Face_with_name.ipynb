# %%
import face_recognition
import cv2
import numpy as np

video_capture = cv2.VideoCapture(0)

sascha_image = face_recognition.load_image_file("C:\\Users\\HP\\Documents\\DectFace\\person\\Sascha.jpg")
sascha_face_encoding = face_recognition.face_encodings(sascha_image)[0]

known_face_encodings = [sascha_face_encoding]
known_face_names = ["Sascha"]
